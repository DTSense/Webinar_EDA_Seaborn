# %% [markdown]
# <a href="https://colab.research.google.com/github/DTSense/Webinar_EDA_Seaborn/blob/master/2_answer/DTSense_EDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# __Load Data__

# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('house_price.csv')
data.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
for col in data.columns:
    print(col, ':', data[col].dtypes)
# Out:
# Id : int64
# MSSubClass : int64
# MSZoning : object
# LotFrontage : float64
# LotArea : int64
# Street : object
# Alley : object
# LotShape : object
# LandContour : object
# Utilities : object
# LotConfig : object
# LandSlope : object
# Neighborhood : object
# Condition1 : object
# Condition2 : object
# BldgType : object
# HouseStyle : object
# OverallQual : int64
# OverallCond : int64
# YearBuilt : int64
# YearRemodAdd : int64
# RoofStyle : object
# RoofMatl : object
# Exterior1st : object
# Exterior2nd : object
# MasVnrType : object
# MasVnrArea : float64
# ExterQual : object
# ExterCond : object
# Foundation : object
# BsmtQual : object
# BsmtCond : object
# BsmtExposure : object
# BsmtFinType1 : object
# BsmtFinSF1 : int64
# BsmtFinType2 : object
# BsmtFinSF2 : int64
# BsmtUnfSF : int64
# TotalBsmtSF : int64
# Heating : object
# HeatingQC : object
# CentralAir : object
# Electrical : object
# 1stFlrSF : int64
# 2ndFlrSF : int64
# LowQualFinSF : int64
# GrLivArea : int64
# ...

# %% [markdown]
# # Non-graphical EDA

# %%
data.describe()
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1460.000000  1460.000000  1201.000000    1460.000000  1460.000000
# mean    730.500000    56.897260    70.049958   10516.828082     6.099315
# std     421.610009    42.300571    24.284752    9981.264932     1.382997
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     365.750000    20.000000    59.000000    7553.500000     5.000000
# 50%     730.500000    50.000000    69.000000    9478.500000     6.000000
# 75%    1095.250000    70.000000    80.000000   11601.500000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  ...  \
# count  1460.000000  1460.000000   1460.000000  1452.000000  1460.000000  ...
# mean      5.575342  1971.267808   1984.865753   103.685262   443.639726  ...
# std       1.112799    30.202904     20.645407   181.066207   456.098091  ...
# ...

# %% [markdown]
# ## Univariate
# ### Central tendency

# %%
data['LotArea'].mean()
# Out:
# 10516.828082191782

# %%
data['LotArea'].median()
# Out:
# 9478.5

# %%
data['LotArea'].mode()
# Out:
# 0    7200
# dtype: int64

# %% [markdown]
# ### Spread tendency

# %%
data['LotArea'].var()
# Out:
# 99625649.6503417

# %%
data['LotArea'].std()
# Out:
# 9981.264932379147

# %%
data['LotArea'].min()
# Out:
# 1300

# %%
data['LotArea'].max()
# Out:
# 215245

# %%
data['LotArea'].quantile(q=0.25)
# Out:
# 7553.5

# %%
data['LotArea'].quantile(q=0.75)
# Out:
# 11601.5

# %% [markdown]
# ## Multivariate

# %%
data.corr()
# Out:
#                      Id  MSSubClass  LotFrontage   LotArea  OverallQual  \
# Id             1.000000    0.011156    -0.010601 -0.033226    -0.028365
# MSSubClass     0.011156    1.000000    -0.386347 -0.139781     0.032628
# LotFrontage   -0.010601   -0.386347     1.000000  0.426095     0.251646
# LotArea       -0.033226   -0.139781     0.426095  1.000000     0.105806
# OverallQual   -0.028365    0.032628     0.251646  0.105806     1.000000
# OverallCond    0.012609   -0.059316    -0.059213 -0.005636    -0.091932
# YearBuilt     -0.012713    0.027850     0.123349  0.014228     0.572323
# YearRemodAdd  -0.021998    0.040581     0.088866  0.013788     0.550684
# MasVnrArea    -0.050298    0.022936     0.193458  0.104160     0.411876
# BsmtFinSF1    -0.005024   -0.069836     0.233633  0.214103     0.239666
# BsmtFinSF2    -0.005968   -0.065649     0.049900  0.111170    -0.059119
# BsmtUnfSF     -0.007940   -0.140759     0.132644 -0.002618     0.308159
# ...

# %%
np.cov(data['LotArea'], data['OverallQual'])
# Out:
# array([[9.96256497e+07, 1.46054827e+03],
#        [1.46054827e+03, 1.91267945e+00]])

# %%
np.corrcoef(data['LotArea'], data['OverallQual'])
# Out:
# array([[1.        , 0.10580574],
#        [0.10580574, 1.        ]])

# %% [markdown]
# ---
# # Graphical EDA

# %%
import seaborn as sns

# %% [markdown]
# ## Univariate
# ### Histogram

# %%
sns.displot(x='YearBuilt', kde=True, data=data)

# %%
sns.histplot(x='YearBuilt', data=data)
# Out:
# <AxesSubplot:xlabel='YearBuilt', ylabel='Count'>

# %% [markdown]
# ### Box plot

# %%
sns.boxplot(x='YearBuilt', data=data)
# Out:
# <AxesSubplot:xlabel='YearBuilt'>

# %%
sns.boxplot(x='YearBuilt', y='SaleCondition', data=data)
# Out:
# <AxesSubplot:xlabel='YearBuilt', ylabel='SaleCondition'>

# %% [markdown]
# ### Violin Plot

# %%
sns.violinplot(x='YearBuilt', data=data)
# Out:
# <AxesSubplot:xlabel='YearBuilt'>

# %%
sns.violinplot(x='YearBuilt', y='CentralAir', data=data)
# Out:
# <AxesSubplot:xlabel='YearBuilt', ylabel='CentralAir'>

# %% [markdown]
# ### Bar plot

# %%
sns.countplot(x='SaleCondition', data=data)
# Out:
# <AxesSubplot:xlabel='SaleCondition', ylabel='count'>

# %%
sns.countplot(x='SaleCondition', hue='CentralAir', data=data)
# Out:
# <AxesSubplot:xlabel='SaleCondition', ylabel='count'>

# %% [markdown]
# ### Line plot

# %%
sns.lineplot(x=data.loc[0:100].index, y='MSSubClass', data=data.loc[0:100])
# Out:
# <AxesSubplot:ylabel='MSSubClass'>

# %% [markdown]
# ---
#
# ## Multivariate
# ### Scatter plot

# %%
sns.scatterplot(x="LotFrontage", y="SalePrice", data=data)
# Out:
# <AxesSubplot:xlabel='LotFrontage', ylabel='SalePrice'>

# %%
sns.scatterplot(x="LotFrontage", y="SalePrice", hue="CentralAir", data=data)
# Out:
# <AxesSubplot:xlabel='LotFrontage', ylabel='SalePrice'>

# %% [markdown]
# ### Bubble plot

# %%
sns.scatterplot(x="LotFrontage", y="SalePrice", data=data, size="YearBuilt")
# Out:
# <AxesSubplot:xlabel='LotFrontage', ylabel='SalePrice'>

# %% [markdown]
# ### Pair plot

# %%
sns.pairplot(data=data[['LotFrontage', 'SalePrice', 'YearBuilt']])

# %%
sns.pairplot(data=data[['LotFrontage', 'SalePrice', 'YearBuilt', 'CentralAir']], hue='CentralAir')

# %% [markdown]
# ### Joint Plot

# %%
sns.jointplot(x='SalePrice', y='YearBuilt', data=data)

# %%
sns.jointplot(x='SalePrice', y='YearBuilt', data=data, hue='CentralAir')

# %% [markdown]
# ## Heat map

# %%
heat_data = pd.pivot_table(data, index='MoSold', columns='YrSold', aggfunc=np.count_nonzero)['SalePrice'].fillna(0)
heat_data
# Out:
# YrSold  2006  2007  2008  2009  2010
# MoSold
# 1       10.0  13.0  13.0  12.0  10.0
# 2        9.0   8.0  10.0  10.0  15.0
# 3       25.0  23.0  18.0  19.0  21.0
# 4       27.0  23.0  26.0  26.0  39.0
# 5       38.0  43.0  38.0  37.0  48.0
# 6       48.0  59.0  51.0  59.0  36.0
# 7       67.0  51.0  49.0  61.0   6.0
# 8       23.0  40.0  29.0  30.0   0.0
# 9       15.0  11.0  17.0  20.0   0.0
# 10      24.0  16.0  22.0  27.0   0.0
# 11      16.0  24.0  17.0  22.0   0.0
# 12      12.0  18.0  14.0  15.0   0.0

# %%
sns.heatmap(heat_data)
# Out:
# <AxesSubplot:xlabel='YrSold', ylabel='MoSold'>

# %%
sub_data = data[['LotArea','LotFrontage','1stFlrSF','2ndFlrSF']]
sns.heatmap(sub_data.corr())
# Out:
# <AxesSubplot:>
